# %%
import cirq
import fractions
import math
import random, time

import numpy as np
import sympy
from typing import Callable, List, Optional, Sequence, Union

import cirq

# %%
"""Defines the modular exponential operation used in Shor's algorithm."""
class ModularExp(cirq.ArithmeticOperation):
    """Quantum modular exponentiation.

    This class represents the unitary which multiplies base raised to exponent
    into the target modulo the given modulus. More precisely, it represents the
    unitary V which computes modular exponentiation x**e mod n:

        V|y⟩|e⟩ = |y * x**e mod n⟩ |e⟩     0 <= y < n
        V|y⟩|e⟩ = |y⟩ |e⟩                  n <= y

    where y is the target register, e is the exponent register, x is the base
    and n is the modulus. Consequently,

        V|y⟩|e⟩ = (U**e|y)|e⟩

    where U is the unitary defined as

        U|y⟩ = |y * x mod n⟩      0 <= y < n
        U|y⟩ = |y⟩                n <= y
    """
    def __init__(
        self, 
        target: Sequence[cirq.Qid],
        exponent: Union[int, Sequence[cirq.Qid]], 
        base: int,
        modulus: int
    ) -> None:
        if len(target) < modulus.bit_length():
            raise ValueError(f'Register with {len(target)} qubits is too small '
                             f'for modulus {modulus}')
        self.target = target
        self.exponent = exponent
        self.base = base
        self.modulus = modulus

    def registers(self) -> Sequence[Union[int, Sequence[cirq.Qid]]]:
        return self.target, self.exponent, self.base, self.modulus

    def with_registers(
            self,
            *new_registers: Union[int, Sequence['cirq.Qid']],
    ) -> cirq.ArithmeticOperation:
        if len(new_registers) != 4:
            raise ValueError(f'Expected 4 registers (target, exponent, base, '
                             f'modulus), but got {len(new_registers)}')
        target, exponent, base, modulus = new_registers
        if not isinstance(target, Sequence):
            raise ValueError(
                f'Target must be a qubit register, got {type(target)}')
        if not isinstance(base, int):
            raise ValueError(
                f'Base must be a classical constant, got {type(base)}')
        if not isinstance(modulus, int):
            raise ValueError(
                f'Modulus must be a classical constant, got {type(modulus)}')
        return ModularExp(target, exponent, base, modulus)

    def apply(self, *register_values: int) -> int:
        assert len(register_values) == 4
        target, exponent, base, modulus = register_values
        if target >= modulus:
            return target
        return (target * base**exponent) % modulus

    def _circuit_diagram_info_(
            self,
            args: cirq.CircuitDiagramInfoArgs,
    ) -> cirq.CircuitDiagramInfo:
        assert args.known_qubits is not None
        wire_symbols: List[str] = []
        t, e = 0, 0
        for qubit in args.known_qubits:
            if qubit in self.target:
                if t == 0:
                    if isinstance(self.exponent, Sequence):
                        e_str = 'e'
                    else:
                        e_str = str(self.exponent)
                    wire_symbols.append(
                        f'ModularExp(t*{self.base}**{e_str} % {self.modulus})')
                else:
                    wire_symbols.append('t' + str(t))
                t += 1
            if isinstance(self.exponent, Sequence) and qubit in self.exponent:
                wire_symbols.append('e' + str(e))
                e += 1
        return cirq.CircuitDiagramInfo(wire_symbols=tuple(wire_symbols))

# %%
"""Function to make the quantum circuit for order finding."""
def make_order_finding_circuit(x: int, n: int) -> cirq.Circuit:
    """Returns quantum circuit which computes the order of x modulo n.

    The circuit uses Quantum Phase Estimation to compute an eigenvalue of
    the unitary

        U|y⟩ = |y * x mod n⟩      0 <= y < n
        U|y⟩ = |y⟩                n <= y

    Args:
        x: positive integer whose order modulo n is to be found
        n: modulus relative to which the order of x is to be found

    Returns:
        Quantum circuit for finding the order of x modulo n
    """
    L = n.bit_length()
    target = cirq.LineQubit.range(L)
    exponent = cirq.LineQubit.range(L, 3 * L + 3)
    return cirq.Circuit(
        cirq.X(target[L - 1]),
        cirq.H.on_each(*exponent),
        ModularExp(target, exponent, x, n),
        cirq.qft(*exponent, inverse=True),
        cirq.measure(*exponent, key='exponent'),
    )

# %%
def process_measurement(result: cirq.Result, x: int, n: int) -> Optional[int]:
    """Interprets the output of the order finding circuit.

    Specifically, it determines s/r such that exp(2πis/r) is an eigenvalue
    of the unitary

        U|y⟩ = |xy mod n⟩  0 <= y < n
        U|y⟩ = |y⟩         n <= y

    then computes r (by continued fractions) if possible, and returns it.

    Args:
        result: result obtained by sampling the output of the
            circuit built by make_order_finding_circuit

    Returns:
        r, the order of x modulo n or None.
    """
    # Read the output integer of the exponent register.
    exponent_as_integer = result.data["exponent"][0]
    exponent_num_bits = result.measurements["exponent"].shape[1]
    eigenphase = float(exponent_as_integer / 2**exponent_num_bits)

    # Run the continued fractions algorithm to determine f = s / r.
    f = fractions.Fraction.from_float(eigenphase).limit_denominator(n)

    # If the numerator is zero, the order finder failed.
    if f.numerator == 0:
        return None

    # Else, return the denominator if it is valid.
    r = f.denominator
    if x**r % n != 1:
        return None
    return r

# %%
def quantum_order_finder(x: int, n: int) -> Optional[int]:
    """Computes smallest positive r such that x**r mod n == 1.

    Args:
        x: integer whose order is to be computed, must be greater than one
           and belong to the multiplicative group of integers modulo n (which
           consists of positive integers relatively prime to n),
        n: modulus of the multiplicative group.
    """
    # Check that the integer x is a valid element of the multiplicative group
    # modulo n.
    if x < 2 or n <= x or math.gcd(x, n) > 1:
        raise ValueError(f'Invalid x={x} for modulus n={n}.')

    # Create the order finding circuit.
    circuit = make_order_finding_circuit(x, n)

    # Sample from the order finding circuit.
    measurement = cirq.sample(circuit)

    # Return the processed measurement result.
    return process_measurement(measurement, x, n)

# %%
def runShor(x ,y) :
    timeBefore = time.perf_counter()
    quantum_order_finder(x, y)
    timeAfter = time.perf_counter()
    totalElapsedTime = timeAfter - timeBefore   
    formattedTotalElapsedTime = "{:.4f}".format(totalElapsedTime)      
    print(str(formattedTotalElapsedTime).replace(".",","))

# %%
# 2,7,8,11 or 13
for x in range(1, 43):  
    runShor(8, 21)
# Out:
# 28,4375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-982d7d8709b0> in <module>
#       1 # 2,7,8,11 or 13
#       2 for x in range(1, 43):
# ----> 3     runShor(8, 21)
#
# <ipython-input-6-18a03db1a466> in runShor(x, y)
#       1 def runShor(x ,y) :
#       2     timeBefore = time.perf_counter()
# ----> 3     quantum_order_finder(x, y)
#       4     timeAfter = time.perf_counter()
#       5     totalElapsedTime = timeAfter - timeBefore
#
# <ipython-input-5-198cc469d1d3> in quantum_order_finder(x, n)
#      17
#      18     # Sample from the order finding circuit.
# ---> 19     measurement = cirq.sample(circuit)
#      20
#      21     # Return the processed measurement result.
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/sim/mux.py in sample(program, noise, param_resolver, repetitions, dtype, seed)
#      78             )
#      79         if protocols.has_unitary(program):
# ---> 80             return sparse_simulator.Simulator(dtype=dtype, seed=seed).run(
#      81                 program=program, param_resolver=param_resolver, repetitions=repetitions
#      82             )
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/work/sampler.py in run(self, program, param_resolver, repetitions)
#      47             Result for a run.
#      48         """
# ---> 49         return self.run_sweep(program, study.ParamResolver(param_resolver), repetitions)[0]
#      50
#      51     def sample(
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/sim/simulator.py in run_sweep(self, program, params, repetitions)
#     100                     measurements[protocols.measurement_key(op)] = np.empty([0, 1])
#     101             else:
# --> 102                 measurements = self._run(
#     103                     circuit=program, param_resolver=param_resolver, repetitions=repetitions
#     104                 )
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/sim/simulator_base.py in _run(self, circuit, param_resolver, repetitions)
#     207         )
#     208         step_result = None
# --> 209         for step_result in self._core_iterator(
#     210             circuit=prefix,
#     211             sim_state=act_on_args,
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/sim/simulator_base.py in _core_iterator(self, circuit, sim_state, all_measurements_are_terminal)
#     181                             op = ops.phase_damp(1).on(*op.qubits)
#     182                     sim_state.axes = tuple(sim_state.qubit_map[qubit] for qubit in op.qubits)
# --> 183                     protocols.act_on(op, sim_state)
#     184                 except TypeError:
#     185                     raise TypeError(f"{self.__class__.__name__} doesn't support {op!r}")
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/protocols/act_on_protocol.py in act_on(action, args, allow_decompose)
#     107     arg_fallback = getattr(args, '_act_on_fallback_', None)
#     108     if arg_fallback is not None:
# --> 109         result = arg_fallback(action, allow_decompose=allow_decompose)
#     110         if result is True:
#     111             return
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/sim/act_on_state_vector_args.py in _act_on_fallback_(self, action, allow_decompose)
#     149         # Try each strategy, stopping if one works.
#     150         for strat in strats:
# --> 151             result = strat(action, self)
#     152             if result is False:
#     153                 break  # coverage: ignore
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/sim/act_on_state_vector_args.py in _strat_act_on_state_vector_from_apply_unitary(unitary_value, args)
#     187     args: 'cirq.ActOnStateVectorArgs',
#     188 ) -> bool:
# --> 189     new_target_tensor = protocols.apply_unitary(
#     190         unitary_value,
#     191         protocols.ApplyUnitaryArgs(
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/protocols/apply_unitary_protocol.py in apply_unitary(unitary_value, args, default, allow_decompose)
#     343     # Try each strategy, stopping if one works.
#     344     for strat in strats:
# --> 345         result = strat(unitary_value, args)
#     346         if result is None:
#     347             break
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/protocols/apply_unitary_protocol.py in _strat_apply_unitary_from_apply_unitary(unitary_value, args)
#     379     op_qid_shape = qid_shape_protocol.qid_shape(unitary_value, (2,) * len(args.axes))
#     380     sub_args = args._for_operation_with_qid_shape(range(len(op_qid_shape)), op_qid_shape)
# --> 381     sub_result = func(sub_args)
#     382     if sub_result is NotImplemented or sub_result is None:
#     383         return sub_result
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/site-packages/cirq/ops/arithmetic_operation.py in _apply_unitary_(self, args)
#     232             # Copy amplitude to new location.
#     233             cast(List[Union[int, slice]], outputs).append(slice(None))
# --> 234             cast(List[Union[int, slice]], inputs).append(slice(None))
#     235             dst[tuple(outputs)] = src[tuple(inputs)]
#     236
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/typing.py in inner(*args, **kwds)
#     263         def inner(*args, **kwds):
#     264             try:
# --> 265                 return cached(*args, **kwds)
#     266             except TypeError:
#     267                 pass  # All real errors (not unhashable args) are raised below.
#
# ~/opt/anaconda3/envs/QUANTUM/lib/python3.9/typing.py in __hash__(self)
#     915
#     916     def __hash__(self):
# --> 917         return hash(frozenset(self.__args__))
#     918
#     919     def __repr__(self):
#
# KeyboardInterrupt:
